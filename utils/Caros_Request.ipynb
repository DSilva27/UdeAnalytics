# %%
import tweepy
import json
import pandas
from data_parser import *

# %%
access_token = "1085741390527692800-v73KoVugFbFTXOu3dkIIxqIYeVLnkt"
access_token_secret = "63mbPu6TZtE9gfsduUk546Va1ouV1PHfhH43pqPDRdRXj"
consumer_key = "gMnJKIu3seBg2ddk6khg49V5w"
consumer_secret = "ST42Rjo0d6MBqJYL2Wbba0o3sSdByN1Ds1D2F0tYoiZN5v1Nrx"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

#Obtains my info

me = api.me() #Hey it's a me! A Terry Hintz

# %%
from pandas.io.json import json_normalize # Normalize semi-structured JSON data into a flat table.

#We are going to select just this columns
cols = ["id","status"]
users = [me._json, me._json]
users_filtered = [{} for i in range(len(users))]

# for user in users:
#     for k in list(user.keys()):
#         if k not in cols:
#             del user[k]

for user_f,user in zip(users_filtered,users):
    for col in cols:
        user_f[col] = user[col]

# %%
df = json_normalize(users_filtered)

df
# Out:
#                     id               status.created_at            status.id  \
# 0  1085741390527692800  Tue Aug 06 01:56:58 +0000 2019  1158557544052379649
# 1  1085741390527692800  Tue Aug 06 01:56:58 +0000 2019  1158557544052379649
#
#          status.id_str                                        status.text  \
# 0  1158557544052379649  @EnCicla Se tiene alguna fecha prevista para a...
# 1  1158557544052379649  @EnCicla Se tiene alguna fecha prevista para a...
#
#    status.truncated status.entities.hashtags status.entities.symbols  \
# 0             False                       []                      []
# 1             False                       []                      []
#
#                        status.entities.user_mentions status.entities.urls  \
# 0  [{'screen_name': 'EnCicla', 'name': 'EnCicla',...                   []
# 1  [{'screen_name': 'EnCicla', 'name': 'EnCicla',...                   []
#
#    ... status.geo  status.coordinates status.place  status.contributors  \
# ...

# %%
me._json
# Out:
# {'id': 1085741390527692800,
#  'id_str': '1085741390527692800',
#  'name': 'Ramon',
#  'screen_name': 'Ramon15862280',
#  'location': '',
#  'profile_location': None,
#  'description': '',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 0,
#  'friends_count': 5,
#  'listed_count': 0,
#  'created_at': 'Thu Jan 17 03:31:34 +0000 2019',
#  'favourites_count': 0,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 3,
#  'lang': None,
#  'status': {'created_at': 'Tue Aug 06 01:56:58 +0000 2019',
#   'id': 1158557544052379649,
#   'id_str': '1158557544052379649',
#   'text': '@EnCicla Se tiene alguna fecha prevista para activar la estación de Parques del Rio?',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'EnCicla',
#      'name': 'EnCicla',
#      'id': 387985142,
#      'id_str': '387985142',
# ...

# %% [markdown]
# class Usuario:
#     def __init__(self,ids):
#         self.followers = [ids]
#         self.friends = [ids]

# %% [markdown]
# $\sqrt{followers\ comun ^2 + following\ comun ^2 } $
