# %%
import pandas as pd
import numpy as np
import json
import re

# %%
from utils.data_parser import parse_from_txt as ptxt

# %%
d0to99    = np.squeeze(ptxt("data/tweets_0to99.json"))
d100to199 = np.squeeze(ptxt("data/tweets_100to199.json"))
d200to299 = np.squeeze(ptxt("data/tweets_200to299.json"))
d300to399 = np.squeeze(ptxt("data/tweets_300to399.json"))
d400toend = np.squeeze(ptxt("data/tweets_400toend.json"))

data = [*d0to99, *d100to199, *d200to299, *d300to399, *d400toend]

usr_id_scrn = pd.read_csv("data/user_id.csv", header = None)

# %%
def RT_REP_Counter(s,users):
    '''
    INPUT: s: list contaning the timelines of our users
           users: dataframe containing id (0) and screen_name (1) of the users we're interested in
           
    OUTPUT: h: dictionary with the following architechture:
                { usr_id : { RT: { rt_usr: freq }, Rep: { Rep_usr: freq } } }
    '''
    
    s = np.squeeze(s) #squeezes the data if there are redudant dimensions
    h = {} 
    
    #Since we are only interested in the users that are part of the csv, I'll just skip the ones
    #that aren't of our interest
    for i in s:
        if i["user_id"] not in users[1].values: continue 
            
        d = {"RT": {}, "Qt": [], "Rep" : {},"NTweets":{},"DQTweets":0}
        
        d["NTweets"] = len(i["tweets"]) 
         
        for tweet in i["tweets"]:
            usrs = re.findall(r"@(\w+)", tweet)
            print(usrs)
            if "QuinteroCalle" in usrs:
                    d["DQTweets"] += 1
                    
            if "RT" in tweet:        
                #usr = re.findall(r"@(\w+)", tweet)[0] #We find all str that start with a @
                usr = usrs[0]
                    
                if usr not in users[0].values: continue
                    
                index = users[users[0] == usr].index[0]
                usr_id = str(users[1][index])
             
                if usr_id in d["RT"]:
                    d["RT"][usr_id] += 1

                else:
                    d["RT"][usr_id] = 1

            else:
                #usrs = re.findall(r"@(\w+)", tweet)
                          
                    
                for j in usrs:
                    if j not in users[0].values: continue
                        
                    index = users[users[0] == j].index[0]
                    usr_id = str(users[1][index])
                        
                    if usr_id in d["Rep"]:
                        d["Rep"][usr_id] += 1

                    else:
                        d["Rep"][usr_id] = 1

        h[i["user_id"]] = d
        
    return h

# %%
counter = RT_REP_Counter(data, usr_id_scrn)
# Out:
# ['hamiltonlawyer1', 'QuinteroCalle', 'elflacomejiam']
# ['MariaFdaCabal']
# ['PedroSantosG', 'petrogustavo', 'ClaudiaLopez']
# ['UnCripudo', 'IvanDaroRestre1', 'Josevargasrol', 'sandavila88', 'QuinteroCalle', 'CesarGaviriaT', 'AlcaldiaItagui']
# ['IvanDaroRestre1', 'Josevargasrol', 'sandavila88', 'QuinteroCalle', 'CesarGaviriaT', 'AlcaldiaItagui', 'EugenioPrieto']
# ['IvanDaroRestre1', 'Josevargasrol', 'sandavila88', 'QuinteroCalle', 'CesarGaviriaT', 'AlcaldiaItagui', 'EugenioPrieto']
# ['sacarmesa', 'Federicoduquep1', 'sandavila88', 'QuinteroCalle', 'Federicoduquep1']
# ['silvioravel']
# ['Laberinto_150', 'QuinteroCalle']
# ['Laberinto_150', 'QuinteroCalle']
# ['maisonalfort', 'QuinteroCalle']
# ['Laberinto_150', 'IchBinDiegoOo', 'QuinteroCalle']
# ['Laberinto_150', 'IchBinDiegoOo', 'QuinteroCalle']
# ['IchBinDiegoOo', 'Laberinto_150', 'QuinteroCalle']
# ['IchBinDiegoOo', 'Laberinto_150', 'QuinteroCalle']
# ['IchBinDiegoOo', 'Laberinto_150', 'QuinteroCalle']
# ['Laberinto_150', 'IchBinDiegoOo', 'QuinteroCalle']
# ['GuzmanJoseVicen']
# ['ROBINASTROLOGO', 'IchBinDiegoOo', 'QuinteroCalle']
# ['ROBINASTROLOGO', 'IchBinDiegoOo', 'QuinteroCalle']
# ['HenaoBernardo']
# ['fergiraldow']
# ['Giocorozo', 'Josevargasrol', 'sandavila88', 'QuinteroCalle', 'CesarGaviriaT', 'AlcaldiaItagui', 'EugenioPrieto']
# ['SintrametroOfic', 'gonzaloalvarezh', 'ENSColombia', 'QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle', 'SintrametroOfic', 'gonzaloalvarezh', 'ALoperadim', 'ENSColombia', 'yoliecheverri', 'CutAntioquia']
# ['ROBINASTROLOGO', 'Laberinto_150', 'QuinteroCalle']
# ['Laberinto_150', 'ROBINASTROLOGO', 'QuinteroCalle']
# ['Laberinto_150', 'ROBINASTROLOGO', 'QuinteroCalle']
# ['ROBINASTROLOGO', 'Laberinto_150', 'QuinteroCalle']
# ['Laberinto_150', 'ROBINASTROLOGO', 'QuinteroCalle']
# ['QuinteroCalle', 'QuinteroCalle']
# ['QuinteroCalle']
# ['elespectador', 'QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# []
# ['JuanCamilopaisa', 'QuinteroCalle']
# ['elespectador', 'MONYRODRIGUEZOF']
# ['Twi_julioc', 'WF_LEAL', 'QuinteroCalle', 'CeDemocratico']
# ['bacillus_sc', 'FiscaliaCol', 'PoliciaColombia']
# ['neroadzurry', 'danielospinam1', 'QuinteroCalle']
# ['neroadzurry', 'danielospinam1', 'QuinteroCalle']
# ['Santialarconu']
# ['Tolaymaruja', 'nadimcomics']
# ['QuinteroCalle']
# ['alvaronavaspere', 'QuinteroCalle']
# ['QuinteroCalle']
# []
# []
# ['wcarmona10', 'QuinteroCalle']
# ['AlejandroMoncaA', 'AlejoPalacioRes', 'QuinteroCalle']
# ['Pelicolombianas']
# ['nicozame1960', 'QuinteroCalle']
# ['camargo_haidy', 'QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['juln_h', 'QuinteroCalle', 'independienteco']
# ['juln_h']
# ['AbelCastao2', 'lewisosba', 'QuinteroCalle']
# ['AbelCastao2', 'alzate_hoyos', 'lewisosba', 'QuinteroCalle']
# ['infopresidencia', 'IvanDuque']
# ['QuinteroCalle']
# ['Kmarggy']
# ['BaldomeroPessoa']
# ['diamaov']
# []
# []
# ['F_Alexander09', 'QuinteroCalle']
# ['vivirpoblado']
# ['vivirpoblado']
# ['Tolaymaruja']
# ['Jhohinpe']
# ['luisbernardov']
# ['Altaestrategica', 'QuinteroCalle', 'jggh1955']
# ['FholguinR', 'QuinteroCalle']
# []
# []
# ['QuinteroCalle']
# []
# ['carlosecaicedo']
# ['IvanDuque', 'infopresidencia']
# ['LuisErnestoGL', 'RevistaSemana']
# ['pormillano', 'PauArizab']
# ['Cjotavillegas', 'nytimes', 'BBCNews', 'bbcmundo', 'el_pais', 'washingtonpost', 'caseysjournal', 'guardia']
# ['Cjotavillegas']
# ['Felipe17400360', 'graffitiborrao', 'nadimcomics']
# ['graffitiborrao', 'nadimcomics']
# ['graffitiborrao', 'nadimcomics']
# ['maritza_serrano', 'IvanDuque', 'EnriquePenalosa', 'petr']
# ['QuinteroCalle']
# ['AFAZ0907', 'QuinteroCalle']
# ['AFAZ0907', 'QuinteroCalle']
# []
# []
# ['GustavoBolivar', 'nadimcomics', 'NanyPardo', 'CathyJuvinao', 'Betocoralg', 'petrogustavo']
# ['IvanCepedaCast', 'elespectador']
# ['GustavoBolivar', 'mindefensa', 'CIDH', 'ONU_es', 'OEA_oficial']
# ['GustavoBolivar']
# ['GustavoBolivar']
# ['60loboestepario', 'Barreja']
# ['Pattismooth', 'juan_alies']
# ['ANKARA300']
# ['hernandorduz', 'LeilaChujfi', 'NataliaDeLaV']
# []
# ['Giocorozo', 'QuinteroCalle', 'elflacomejiam']
# ['DeysyMilena2']
# ['desararpo']
# ['petrogustavo', 'bluradio']
# ['ghitis']
# ['MafeCarrascal']
# ['Lizz_Bennet']
# ['matadoreltiempo']
# ['RoyBarreras', 'mluciaramirez', 'MarianaGarcesG']
# []
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['cheshire2225']
# ['LeonelGutierre8']
# []
# ['ktikariza']
# ['jucaarmar', 'QuinteroCalle']
# ['F_Alexander09', 'QuinteroCalle']
# ['QuinteroCalle']
# ['jggh1955', 'OmarFlorezV', 'QuinteroCalle', 'PoliciaColombia', 'FiscaliaCol', 'AlcaldiadeMed', 'MinInterior', 'PoliciaMedellin']
# ['QuinteroCalle', 'AlcaldiadeMed', 'petrogustavo', 'AlvaroUribeVel', 'UltimaHoraBLU']
# ['Juanaafanador1', 'EnriquePenalosa', 'bienconcreto', 'davidgarciarod']
# ['PrensaRural', 'MAFAPOBOGOTA', 'Ccajar', 'petrogustavo', 'GustavoBolivar', 'AidaAvellaE', 'intiasprilla', 'HOLLMANMORRIS']
# ['ElJuliSastoque', 'BluRadioCo']
# ['marianietog99', 'ElJuliSastoque']
# ['QuinteroCalle', 'MONYRODRIGUEZOF']
# ['xjusticianimal']
# ['SABRINAVALERI20']
# ['DilMarin8', 'AsulfBass']
# ['richizuluaga', 'JDValde']
# []
# []
# []
# ['JuanCaElnegro', 'rabodeajip', 'sergioalzatech']
# ['chigo58336410', 'jfhhoyos', 'HassNassar', 'RevistaSemana', 'saludhernandezm', 'VickyDavilaH', 'DCoronell', 'MJDuzan']
# []
# ['ROBINASTROLOGO', 'IchBinDiegoOo', 'Laberinto_150', 'QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['jflafaurie', 'jjaramillo61']
# ['EdnaBonillaSeba', 'jflafaurie', 'jflafaurie', 'AlejoPalacioRes']
# ['VickyDavilaH', 'VictoriaBxE']
# ['AlejoPalacioRes', 'UneesCol', 'ACREESCOL']
# ['diegomatteus']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['Betocoralg']
# ['JessLopera1']
# ['QuinteroCalle']
# ['juan_alies', 'rccs_1984']
# ['marantoniaserna']
# ['ClaMoralesM']
# ['ClaMoralesM']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['RafaelG10099924']
# ['ElliotAldersonD']
# ['QuinteroCalle', 'Mujer_Mamerta']
# ['Oritav0y']
# ['__carolinamar', 'Jennyferpbn']
# []
# []
# ['BajoTurmeque']
# ['QuinteroCalle']
# ['lfredobocanegra']
# ['QuinteroCalle']
# []
# ['QuinteroCalle', 'juan_alies']
# ['MAFAPOBOGOTA']
# ['WF_LEAL', 'samuelrestrepo8', 'QuinteroCalle', 'CeDemocratico']
# ['cari513']
# ['juliomario55555']
# ['anturio06']
# ['frmesa']
# ['JudyCure']
# ['fernapaba']
# ['QuinteroCalle', 'juliomario55555']
# ['wiloscova07', 'as', 'es']
# ['LuzMBernalParra']
# ['jandresortega20', 'CorteSupremaJ']
# []
# ['CarlosEParedes2', 'YezidZarateg']
# ['humanjad']
# ['ahainc1980', 'fdbedout']
# ['QuinteroCalle']
# ['LINDACRIOLLO', 'HOLLMANMORRIS', 'petrogustavo', 'UP_Colombia', 'LupeMohawk']
# ['JudyCure', 'ShekoPC', 'CeDemocratico']
# ['QuinteroCalle']
# ['MafeCarrascal']
# ['DonIzquierdo_']
# ['AlvaroUribeVel']
# ['andrefelgiraldo']
# []
# ['PizarroMariaJo', 'AidaAvellaE', 'DavidRacero', 'wilsonariasc', 'GustavoBolivar', 'petrogustavo']
# ['niczaro2']
# ['MJDuzan', 'MeDicenWally', 'mapatilla', 'ActualidadRT', 'CeciliaOrozcoT', 'FiscaliaCol', 'UNPColombia', 'inafinogenova']
# ['IrreverentesCol', 'QuinteroCalle']
# ['diarioas']
# ['GustavoBolivar']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['AlfredoRamosM']
# ['QuinteroCalle']
# ['bettycriticonaa']
# ['helenordonez', 'AlvaroUribeVel']
# ['AlvaroUribeVel']
# ['AlvaroUribeVel']
# ['martinhroman', 'RadioRedMedelli', 'FicoGutierrez']
# ['ghitis', 'ELTIEMPO']
# ['IvanDuque', 'UNGRD']
# ['Uriasv']
# ['Uriasv']
# ['darioarenasv', 'AlejoPalacioRes']
# ['darioarenasv']
# ['Betocoralg']
# ['patoBarros69']
# ['QuinteroCalle']
# ['AlargueCaracol']
# ['QuinteroCalle', 'luisbernardov']
# ['QuinteroCalle']
# ['CorteSupremaJ', 'CorteSupremaJ']
# ['MelissaDelahoz']
# ['SaninPazC']
# ['QuinteroCalle']
# ['DELAESPRIELLAE', 'petrogustavo']
# ['efrapotter']
# ['F_Alexander09', 'QuinteroCalle']
# ['F_Alexander09', 'QuinteroCalle']
# ['nadimcomics', 'FLIP_org']
# ['LAAZCARATE']
# ['LAAZCARATE', 'VickyDavilaH']
# ['LAAZCARATE']
# ['aire57']
# ['skhunt92']
# ['angeln1981', 'pedroferneyc', 'VickyDavilaH', 'JuanManSantos']
# ['petrogustavo']
# ['QuinteroCalle']
# ['EstamosConGalan']
# ['QuinteroCalle']
# ['lunadavid']
# ['MariGomezGirald', 'MujeresConGalan', 'BogotaX']
# []
# ['RevistaSemana']
# ['RevistaSemana', 'CorteSupremaJ', 'CorteSupremaJ']
# ['BluRadioCo', 'saludhernandezm']
# ['elespectador']
# ['elespectador', 'QuinteroCalle']
# ['IvanDuque', 'infopresidencia', 'JosepBorrellF']
# ['luisjalmar']
# ['Ana_Trina']
# ['LAPacifiKA']
# ['vergaraangela_']
# ['nataliazapata20', 'oscaramontoya', 'Daniela77912741', 'EnriquePenalosa']
# ['agaviria97']
# ['agaviria97']
# ['Lynx_581']
# ['mariacastro1111']
# ['mariacastro1111']
# ['FelicianoValen']
# ['elespectador']
# ['TigresOficial']
# ['SomosTigres']
# ['andres_aristi', 'SoldadoStranger']
# ['SoldadoStranger']
# ['andres_aristi', 'SoldadoStranger', 'JocNanclares']
# ['SaqueLargoWin']
# ['jflafaurie']
# ['CeciliaFdezdeC']
# ['castrojuanjose']
# ['QuinteroCalle']
# ['bacillus_sc']
# []
# ['QuinteroCalle']
# []
# []
# []
# []
# []
# ['efrainrico1', 'Marianiniecheve']
# ['lcvelez']
# ['melbitacastro', 'PabloSolanoMat1']
# ['FilomenaFareseo', 'lafm']
# ['monalexan', 'MiguelUribeT']
# ['AnaKGomezR']
# ['Estewatt']
# ['C_Pueblos']
# ['andrescamachom_', 'XRBogota', 'Movicecol', 'CumbreUrbana', 'DefensoriaCol', 'charry_manager', 'PizarroMariaJo', 'DavidRacero']
# ['andrescamachom_']
# ['Santo_Venganza']
# ['el_pais']
# ['el_pais']
# ['QuinteroCalle']
# ['AlvaroUribeVel']
# []
# ['IsabelMeja14']
# []
# ['AlarconUbaldo16']
# ['bacillus_sc']
# ['Pfrobledo']
# ['Paterpau']
# ['QuinteroCalle']
# ['BajoTurmeque']
# ['QuinteroCalle']
# ['PauAguinaga']
# ['AndresSantana08', 'QuinteroCalle']
# ['QuinteroCalle', 'Genteconvos_']
# ['QuinteroCalle', 'AlHerDeBa', 'GodColombiano']
# ['EIExpedienteCol']
# ['jbagbam74']
# []
# ['ponchoarcos', 'jflafaurie']
# []
# ['ponchoarcos', 'QuinteroCalle', 'petrogustavo']
# ['LaMamert4']
# []
# []
# []
# ['carolinaramirez']
# ['jorgemorenovel', 'QuinteroCalle']
# ['desararpo']
# ['QuinteroCalle']
# ['Juanaafanador1', 'EnriquePenalosa', 'bienconcreto']
# ['saramatt03']
# ['QuinteroCalle']
# ['Alonrop']
# ['QuinteroCalle']
# ['jhonglo1']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['ghitis', 'mgomezmartinez']
# ['Pseudos1401', 'pablovareladdhh', 'QuinteroCalle']
# ['USCOoficial']
# ['QuinteroCalle']
# ['fdbedout']
# ['scruff888']
# ['DIvan_Gzz']
# ['madameperine', 'IvanDuque']
# ['PaulFaul66', 'MONYRODRIGUEZOF', 'EnriquePenalosa']
# ['jorgeacostav', 'MONYRODRIGUEZOF']
# ['QuinteroCalle', 'MONYRODRIGUEZOF']
# ['AlirioUribeMuoz', 'Ccajar', 'IvanCepedaCast', 'IvanDuque', 'petrogustavo', 'DefendamosPaz', 'dianamotavo', 'Movicecol']
# ['MalejandraAriza']
# ['AlirioUribeMuoz', 'IvanDuque', 'ONIC_Colombia', 'Ccajar', 'IvanCepedaCast', 'DefendamosPaz', 'Movicecol', 'GustavoBolivar']
# ['CNNEE']
# ['JoseRadaRoldan', 'QuinteroCalle', 'petrogustavo', 'AlfredoRamosM']
# ['cardenasjorgee', 'CorteSupremaJ']
# ['matheuandres90', 'PabloDavalos63']
# ['LAPlazasVega']
# ['GustavoRugeles', 'CorteSupremaJ', 'IvanCepedaCast']
# ['WF_LEAL', 'Gabigap', 'QuinteroCalle', 'CeDemocratico']
# ['lcvelez']
# ['Estewatt']
# ['C_Pueblos']
# ['andrescamachom_', 'XRBogota', 'Movicecol', 'CumbreUrbana', 'DefensoriaCol', 'charry_manager', 'PizarroMariaJo', 'DavidRacero']
# ['andrescamachom_']
# ['Santo_Venganza']
# ['el_pais']
# ['el_pais']
# ['QuinteroCalle']
# ['AlvaroUribeVel']
# []
# ['IsabelMeja14']
# []
# ['AlarconUbaldo16']
# ['bacillus_sc']
# ['Pfrobledo']
# ['Paterpau']
# ['QuinteroCalle']
# ['BajoTurmeque']
# ['QuinteroCalle']
# ['PauAguinaga']
# ['AndresSantana08', 'QuinteroCalle']
# ['QuinteroCalle', 'Genteconvos_']
# ['QuinteroCalle', 'AlHerDeBa', 'GodColombiano']
# ['EIExpedienteCol']
# ['jbagbam74']
# []
# ['ponchoarcos', 'jflafaurie']
# []
# ['ponchoarcos', 'QuinteroCalle', 'petrogustavo']
# ['LaMamert4']
# []
# []
# []
# ['carolinaramirez']
# ['jorgemorenovel', 'QuinteroCalle']
# ['desararpo']
# ['QuinteroCalle']
# ['Juanaafanador1', 'EnriquePenalosa', 'bienconcreto']
# ['saramatt03']
# ['QuinteroCalle']
# ['Alonrop']
# ['QuinteroCalle']
# ['jhonglo1']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['ghitis', 'mgomezmartinez']
# ['Pseudos1401', 'pablovareladdhh', 'QuinteroCalle']
# ['USCOoficial']
# ['QuinteroCalle']
# ['fdbedout']
# ['scruff888']
# ['DIvan_Gzz']
# ['madameperine', 'IvanDuque']
# ['PaulFaul66', 'MONYRODRIGUEZOF', 'EnriquePenalosa']
# ['jorgeacostav', 'MONYRODRIGUEZOF']
# ['QuinteroCalle', 'MONYRODRIGUEZOF']
# ['AlirioUribeMuoz', 'Ccajar', 'IvanCepedaCast', 'IvanDuque', 'petrogustavo', 'DefendamosPaz', 'dianamotavo', 'Movicecol']
# ['MalejandraAriza']
# ['AlirioUribeMuoz', 'IvanDuque', 'ONIC_Colombia', 'Ccajar', 'IvanCepedaCast', 'DefendamosPaz', 'Movicecol', 'GustavoBolivar']
# ['CNNEE']
# ['JoseRadaRoldan', 'QuinteroCalle', 'petrogustavo', 'AlfredoRamosM']
# ['cardenasjorgee', 'CorteSupremaJ']
# ['matheuandres90', 'PabloDavalos63']
# ['LAPlazasVega']
# ['GustavoRugeles', 'CorteSupremaJ', 'IvanCepedaCast']
# ['WF_LEAL', 'Gabigap', 'QuinteroCalle', 'CeDemocratico']
# ['lcvelez']
# ['QuinteroCalle']
# ['DAYRXN', 'QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['LaAnate', 'olgarusu', 'palomaparro']
# ['RestrepoJCamilo']
# ['QuinteroCalle', 'IvanDuque']
# ['ClaudiaLopez', 'CarlosFGalan', 'MiguelUribeT']
# ['HOLLMANMORRIS', 'EnriquePenalosa']
# ['AlexKleinO', 's', 'nytimes']
# ['QuinteroCalle', 'QuinteroCalle']
# ['MariaFdaCabal']
# ['Lizz_Bennet', 'DonGato_7521']
# ['JuanCamilo', 'pilar_rod', 'Fabianmendoza', 'Amaltea_lav', 'clarasandoval', '2150dePam', 'ghitis', 'SophyCh_E', 'FernanMartinez']
# ['JuanCamilo']
# ['Sofia444D']
# ['DiegoSa46895811', 'LeilaChujfi', 'cegato22', 'PauArizab']
# ['sotodoriamanuel', 'magato0730', 'DELAESPRIELLAE']
# ['cardenasjorgee', 'CorteSupremaJ']
# ['LaGrondonaTwitt', 'TigresOficial']
# ['manuduquehh']
# ['QuinteroCalle', 'Genteconvos_']
# ['Fannygonzalezt', 'EnvigadoFC']
# ['nacionaloficial']
# ['diarioas']
# ['JulianJaraUribe', 'QuinteroCalle']
# ['queiyei']
# []
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['H_U_V_A']
# ['PaisMenosPeor']
# ['carlangas_mier', 'AlbertoBernalLe']
# ['guidodevacas', 'AlbertoBernalLe']
# ['WRadioColombia', 'AlisAdiaz']
# []
# ['AlbertoBernalLe', 'guidodevacas']
# ['Paisademedellin', 'efrapotter', 'santimolina30', 'JJTrellezV', 'QuinteroCalle']
# ['QuinteroCalle']
# ['EstebanSantos10']
# ['GustavoBolivar']
# []
# ['CorteSupremaJ', 'CorteSupremaJ']
# ['GustavoBolivar']
# ['wiloscova07']
# ['BaldomeroPessoa', 'QuinteroCalle']
# []
# []
# ['QuinteroCalle']
# []
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['MAFAPOBOGOTA']
# ['YeimisEcheverry']
# []
# []
# ['LuisWalteros3', 'CABLENOTICIAS']
# ['QuinteroCalle', 'GoezTeresita']
# ['Nessnio']
# ['favi1976', 'iShosholoza']
# ['campesinobeso']
# ['tomatinesdulces']
# ['CosmicaBasura21']
# []
# []
# []
# ['ELTIEMPO']
# ['gusgomez1701', 'MafeCarrascal', 'DELAESPRIELLAE']
# ['QuinteroCalle']
# ['DELAESPRIELLAE', 'petrogustavo']
# ['QuinteroCalle']
# ['armando_regil', 'Fercho81jaimes']
# ['MaihenH', 'gataraya', 'jguaido']
# ['zarcohpx8']
# ['ANONIMU50817107']
# ['MuySuFrida']
# ['Mariahuribe1', 'petrogustavo']
# ['Urruchurtu']
# ['Urruchurtu']
# ['QuinteroCalle', 'QuinteroCalle']
# ['MafeCarrascal']
# ['armando_regil', 'Fercho81jaimes']
# ['MaihenH', 'gataraya', 'jguaido']
# ['zarcohpx8']
# ['ANONIMU50817107']
# ['MuySuFrida']
# ['Mariahuribe1', 'petrogustavo']
# ['Urruchurtu']
# ['Urruchurtu']
# ['QuinteroCalle', 'QuinteroCalle']
# ['MafeCarrascal']
# ['PJUAGIBIOY', 'CGR_Colombia', 'ArielAnaliza']
# ['PoliciaDepuy']
# ['yumbila']
# ['VelascoNatalia_', 'ICBFColombia', 'CarlosAparicioP', 'chialloreda', 'fonseca_zulma', 'JulianaCortesG']
# ['VelascoNatalia_']
# ['MabelLaraNews']
# ['marcelaboyaca', 'glorialozanob', 'alejroca', 'soylajornalista', 'MarianaDuarteVa', 'PaolaRojas_C', 'LauraHincapie26']
# ['ktikariza', 'merv59', 'IvanDuque']
# ['YolandaRuizCe']
# ['QuinteroCalle']
# []
# ['samuelrosasc', 'CorpoRosaBlanca', 'elespectador', 'ComisionDeLaVer', 'FranciscoDeRoux']
# []
# []
# ['CarrillonavasG']
# ['PirryOficial', 'RevistaSemana', 'PirryOficial']
# ['eduardouribeu']
# ['carlos03713611', 'IvanCepedaCast', 'JERobledo']
# ['andresdapena198', 'ruorco', 'drvargasquemba', 'CorpoRosaBlanca', 'elespectador', 'ONU_es']
# ['estrano_luis', 'La_Ely__', 'ActualidadRT']
# ['periodistica', 'QuinteroCalle']
# ['anibalgaviria']
# ['anibalgaviria']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['AndreaArtehaga1']
# ['JERobledo', 'ClaudiaLopez']
# ['_carlosduque', 'ClaudiaLopez']
# ['ErnestoPatioRam']
# ['MelissaDelahoz']
# ['QuinteroCalle', 'MONYRODRIGUEZOF']
# ['QuinteroCalle']
# ['Jorgomezpinilla', 'RevistaSemana']
# ['hernandorduz', 'NataliaDeLaV']
# ['EstherCastroL']
# ['Smusddb', 'IrreverentesCol', 'ANIABELLO_R', 'QuinteroCalle']
# ['QuinteroCalle', 'duran_schneider']
# ['Marianiniecheve', 'duran_schneider']
# ['ActualidadPol', 'AlcaldiadeMed', 'AlfredoRamosM', 'BeatrizRave', 'QuinteroCalle']
# ['ActualidadPol', 'GobAntioquia', 'anibalgaviria', 'andresguerraho', 'Ivan_MauricioP', 'Juancamilorpog']
# ['AdaColau']
# ['denterd', 'jcanadellb']
# ['InesArrimadas']
# ['lalertacanal']
# ['AturadaCatalana']
# ['naciodigital', 'AdaColau']
# []
# ['toni_florido']
# ['CDRLesCorts']
# []
# ['QuinteroCalle', 'Hail_Gu']
# ['JoseCuelloB', 'JairoRRoaS']
# ['MariaFdaCabal']
# ['jflafaurie']
# ['BabeRott', 'MariaFdaCabal']
# ['mariapa05527055']
# ['GustavoBolivar']
# ['AbelCastao2', 'AndresSantana08', 'QuinteroCalle']
# ['NancyFiallo', 'QuinteroCalle', 'Reiniciarco']
# ['AnieVelasquez__']
# ['MONYRODRIGUEZOF']
# ['QuinteroCalle']
# ['QuinteroCalle', 'ricardopuentesm']
# ['VickyDavilaH', 'EnriquePenalosa', 'Rodrigo_Lara_']
# ['ChriGarces', 'MargaritaRepo', 'IvanDuque']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['GustavoRugeles', 'luisfelipehenao']
# ['NoticiasCaracol']
# ['JosPastr']
# ['MariaFdaCabal']
# ['FernanMartinez']
# ['jflafaurie']
# ['PirryOficial']
# ['Santialarconu']
# ['JERobledo', 'ClaudiaLopez']
# ['PorLosAnimales_']
# ['QuinteroCalle']
# ['jerojasrodrigue']
# ['MarmotaClub']
# ['skepticaesar', 'HOLLMANMORRIS']
# ['LupeMohawk']
# ['QuinteroCalle']
# ['PinoCalad', 'machecor']
# ['JulianRoman', 'petrogustavo']
# ['MartinSantosR']
# ['MeDicenWally', 'petrogustavo']
# ['QuinteroCalle']
# ['DELAESPRIELLAE', 'petrogustavo', 'MafeCarrascal', 'DELAESPRIELLAE']
# ['DELAESPRIELLAE', 'petrogustavo']
# ['bettycriticonaa', 'HOLLMANMORRIS']
# ['jerojasrodrigue']
# ['Estamos_Listas', 'QuinteroCalle', 'felipepalau', 'RicharSierraA']
# ['Movicecol']
# ['MafeCarrascal']
# ['DefensoriaCol', 'personeriamed', 'Mineducacion']
# []
# ['CABLENOTICIAS', 'Indepaz']
# []
# ['OBS_defenders', 'CSPP_']
# ['GarantiasPSG']
# ['CeciliaOrozcoT']
# ['SaulBar1']
# ['intiasprilla', 'Rodrigo_Lara_']
# ['AlirioUribeMuoz']
# ['Inconciencio']
# ['darioarenasv']
# ['Contagioradio1']
# ['Julian_Sebas']
# ['Alejandrapenha']
# ['QuinteroCalle']
# ['vgmz_']
# ['ActualidadPol', 'GobAntioquia', 'anibalgaviria', 'andresguerraho', 'Ivan_MauricioP', 'Juancamilorpog']
# ['ActualidadPol', 'AlcaldiadeMed', 'AlfredoRamosM', 'BeatrizRave', 'QuinteroCalle']
# ['ActualidadPol', 'GobAntioquia']
# ['ActualidadPol', 'GobAntioquia', 'anibalgaviria', 'andresguerraho', 'Ivan_MauricioP', 'Juancamilorpog']
# ['ActualidadPol', 'AlcaldiadeMed']
# ['JuanEsMejiaGob', 'andresguerraho']
# ['YomeLlamo']
# ['DIRECTVSportsCo', 'titopuccettic', 'AdrianMagnoli', 'johamorenoG']
# ['QuinteroCalle', 'Genteconvos_']
# ['SaqueLargoWin', 'stevenarce']
# ['SaqueLargoWin']
# []
# []
# ['ClaMoralesM', 'luisyepesb', 'MrCulebra', 'anacrisrestrepo']
# ['QuinteroCalle']
# []
# ['castano_pin', 'rncn122222', 'richizuluaga']
# ['rncn122222', 'richizuluaga']
# ['ElGranDebate', 'nancySua_']
# ['ANNALVAREZG', 'FarydMondragon', 'mluciaramirez', 'IvanDuque', 'RubenPinzonHdez', 'gurozu', 'LeilaChujfi', 'JUANCAELBROKY']
# ['JuanElConteston', 'MadameFelix']
# ['JackDeLaConcha']
# ['MONYRODRIGUEZOF']
# ['QuinteroCalle']
# ['CardonaWbeimar']
# ['LilianaDiazCruz', 'CeDemocratico']
# ['DianaMendezD', 'NoticiasCaracol']
# ['RubenRo28494193', 'GustavoBolivar', 'JUANCAELBROKY']
# ['QuinteroCalle']
# ['flaca65']
# ['HelenUribista', 'CarlosFGalan']
# ['QuinteroCalle']
# ['ffoottooss']
# []
# ['MAFAPOBOGOTA']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['Romana_FARC', 'petrogustavo', 'EnriquePenalosa']
# ['pablocormolina', 'Betocoralg']
# ['saludhernandezm', 'semana']
# ['HassNassar']
# ['alexjune71']
# ['fdbedout']
# ['QuinteroCalle']
# ['JuanCamiloME', 'Juancamilorpog']
# ['QuinteroCalle']
# ['Juancamilorpog']
# ['QuinteroCalle']
# ['petrogustavo', 'petrogustavo']
# ['QuinteroCalle']
# ['AlfredoRamosM']
# ['SaVanesCa', 'DELAESPRIELLAE', 'petrogustavo']
# ['GobAntioquia']
# []
# ['HassNassar', 'RevistaSemana', 'saludhernandezm']
# ['JhonnyNicaragua']
# ['Hennypocahontas']
# ['juan_alies', 'IvanDuque']
# ['cesaren79138188']
# ['nataliazapata20', 'JimnezHumberto1', 'PabloSolanoMat1', 'QuinteroCalle']
# ['JimnezHumberto1']
# ['F_Alexander09', 'QuinteroCalle']
# ['bacillus_sc']
# ['efrainrico1', 'CorteSupremaJ']
# ['callynocallo2']
# ['EcheverriAdolfo', 'ActualidadPol', 'AlcaldiadeMed', 'AlfredoRamosM', 'BeatrizRave', 'QuinteroCalle']
# ['ActualidadPol', 'AlcaldiadeMed', 'AlfredoRamosM', 'BeatrizRave', 'QuinteroCalle']
# ['juanf178', 'PartidoMIRA']
# ['AlfredoRamosM']
# ['GustavoRugeles', 'luisfelipehenao']
# []
# ['jg_dominguez']
# ['EnriquePenalosa']
# ['RuidoEnLaRed', 'lopezobrador_']
# ['DanielRaisbeck']
# ['JuanManSantos']
# ['Sir_Candelario', 'JuanGarciaGira', 'safri89', 'QuinteroCalle']
# ['JulianJaraUribe', 'QuinteroCalle']
# ['DavidRacero']
# ['FVallejoQuotes']
# ['JulianRoman']
# ['QuinteroCalle']
# ['petrogustavo']
# ['FranciaMarquezM', 'saludhernandezm']
# ['QuinteroCalle', 'rabodeajip']
# ['CatalinaGomezS', 'AsinomasDigo']
# ['dimartillo', 'FLIP_org', 'BluRadioCo', 'CaracolRadio', 'NoticiasRCN', 'YolandaRuizCe', 'juanitacatano', 'jciragorri']
# ['QuinteroCalle']
# ['Oscarpanesso', 'Jhonjagudelo', 'sergio_fajardo']
# ['IgnArizmendi']
# ['Elmefi20011', 'ghitis', 'RamiroBejaranoG']
# ['C88Caesar', 'ghitis']
# ['Revista_iF', 'todoscolombia', 'EduardoJFloresF']
# ['Marsum49', 'todoscolombia']
# ['merv59']
# []
# ['alkaravan']
# ['abc_es']
# ['Eclides3']
# ['JudyCure']
# ['QuinteroCalle', 'mariumega']
# ['QuinteroCalle']
# ['juan_alies', 'IvanDuque']
# ['JavierAngel2050', 'Javier067652121', 'juan_alies']
# ['Nick_Rivers_19', 'DCoronell', 'RevistaSemana']
# ['LuisErnestoGL', 'RevistaSemana']
# ['LuisErnestoGL', 'RevistaSemana']
# ['linulera']
# ['Sachaka7', 'IvanDuque']
# ['FisicoImpuro']
# ['SandinoVictoria']
# ['LaOrejaRoja']
# ['luisrodevia']
# ['fercasa14', 'EsperancitaUrib']
# ['linaR03']
# ['gener_usuga', 'COL_EJERCITO']
# ['crotatas']
# ['QuinteroCalle']
# ['RotaviskyC']
# ['ElFokinDiego']
# ['MiltonQuinonesC', 'QuinteroCalle']
# ['AlcaldiadeMed']
# ['QuinteroCalle']
# ['fuedicho']
# ['alfreparedes', 'EnriquePenalosa']
# ['shidura26']
# ['ElRepublicano09', 'EnriquePenalosa']
# ['JERobledo', 'ClaudiaLopez']
# ['DELAESPRIELLAE', 'petrogustavo']
# ['HassNassar', 'RevistaSemana', 'saludhernandezm']
# ['HassNassar']
# ['HassNassar', 'saludhernandezm', 'RevistaSemana']
# ['RafaNietoLoaiza']
# ['EstebanSantos10', 'sergiolonzu']
# ['elarkeologo']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['IvanTovar01']
# ['ErnestoPatioRam']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# []
# ['QuinteroCalle', 'thiagocampo']
# ['DELAESPRIELLAE', 'Pfrobledo']
# ['proferasputon', 'DELAESPRIELLAE', 'petrogustavo']
# ['DELAESPRIELLAE', 'petrogustavo']
# ['QuinteroCalle']
# []
# ['AnimalesBOG', 'Ambientebogota', 'SectorSalud', 'GobiernoBTA', 'CanalCapital', 'Citytv', 'NoticiasRCN', 'BluRadioCo', 'EFEnoticias']
# ['AndresTesla', 'juliherrerap', 'MONYRODRIGUEZOF', 'piedrahitangela', 'AnimalesBOG', 'PoliciaBogota', 'PoliciaColombia', 'Bogota']
# ['AndresS23834958', 'Pfrobledo']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['SandinoVictoria']
# ['alebaraya']
# ['Ignorolito', 'MafeCarrascal', 'DELAESPRIELLAE']
# []
# ['MafeCarrascal']
# ['EstherCastroL']
# ['TinoasprillaH', 'PibeValderramaP', 'JJTrellezV', 'higuitarene', 'alanshearer', 'NUFC', 'byAngelicaC']
# ['PauArizab']
# ['QuinteroCalle', 'freydher']
# ['juan_alies', 'IvanDuque', 'PoliciaColombia']
# ['jpsartre06']
# ['MafeCarrascal', 'DELAESPRIELLAE']
# ['adn40', 'ohernandezb']
# ['masaldarlon']
# ['Nicky05203074']
# ['ArgiroCasta58', 'ANIABELLO_R']
# ['AdamSmithFree']
# ['ASubirath']
# ['GlediaCubides', 'saludhernandezm']
# ['AlbertoBernalLe']
# ['el_pais']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['Sopadebanano']
# ['Sopadebanano']
# ['alfreparedes']
# ['bladimirs20']
# ['RafaelG10099924']
# ['merv59']
# ['HernandoGP']
# ['Tuitero1A']
# ['cari513']
# ['Cony_martinez_']
# ['QuinteroCalle', 'mariapa05527055']
# ['ktikariza']
# ['SanEazzy', 'auronplay', 'werevertumorro']
# ['auronplay']
# []
# ['Jhonmontoyota1', 'QuinteroCalle']
# ['Jhonmontoyota1', 'QuinteroCalle']
# ['MiguelUribeT']
# ['SugarMomMom']
# []
# ['Tolaymaruja']
# ['QuinteroCalle']
# ['independienteco']
# ['Juanparal']
# ['crfung']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['AidaAvellaE']
# ['DiscussingFilm']
# ['sacarmesa', 'AlfredoRamosM']
# ['Sofia_Hincapie', 'facultadderecho', 'cristian10diaz', 'EAFIT', 'DSuarezT']
# ['facultadderecho', 'EAFIT', 'facultadderecho']
# ['IGarzonVallejo', 'Avianca']
# ['JEP_Colombia', 'JEP_Colombia']
# ['FernanMartinez', 'MiguelUribeT', 'AlvaroUribeVel']
# ['david_aml', 'jcvelezuribe']
# ['jcvelezuribe']
# ['QuinteroCalle']
# ['pilas13631404', 'JOHNBOLIVARACOS', 'CCSILVA86', 'Marcoscera1518', 'Andy_RomeroC', 'Carloscadena64', 'claudiamzuleta']
# ['CaigaQuienCaig8', '12345dubalier', 'cmgnecco', 'luismonsalvo']
# ['QuinteroCalle']
# ['EnriquePenalosa']
# ['IvanDuque']
# ['QuinteroCalle']
# ['QuinteroCalle']
# []
# ['QuinteroCalle']
# ['Reytorre']
# ['QuinteroCalle']
# ['PartidoLiberal', 'CNE_COLOMBIA', 'VictorLRamirez', 'CrisantoPizo', 'CJBONILLASOTO', 'velascoluisf', 'fcarrilloflorez', 'PGN_COL']
# ['gener_usuga']
# ['gener_usuga']
# ['NancyPatricia_G', 'DefensoriaCol', 'MinInterior', 'PoliciaColombia', 'FiscaliaCol', 'MAPPOEA', 'UNPColombia', 'PGN_COL']
# ['IvanCepedaCast', 'EnriquePenalosa', 'fcarrilloflorez', 'DefensoriaCol', 'CGR_Colombia', 'FiscaliaCol']
# ['IvanCepedaCast', 'EnriquePenalosa']
# ['tulipanojoyeria']
# ['Tatianagj92']
# ['elmeIIo', 'WilsonP81684382']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['_carlosduque', 'IvanDuque', 'JuanManSantos']
# ['MiguelUribeT']
# ['ClaudiaLopez', 'CarlosFGalan']
# ['alfreparedes', 'EnriquePenalosa']
# ['esantosmolano', 'HOLLMANMORRIS']
# ['juan_alies', 'IvanDuque']
# ['QuinteroCalle', 'MarceJara2018']
# ['QuinteroCalle']
# ['aljimenezber', 'CorteSupremaJ', 'yonydumar', 'ALVAROHPRADA']
# ['Barreja']
# ['Ivager69', 'chinvila23', 'ContraloriaBta', 'UNIONEUROPEA', 'OEA_oficial', 'UN', 'antonioguterres', 'mbachelet', 'onuhabitat']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['SugarMomMom']
# ['HOLLMANMORRIS']
# ['QuinteroCalle']
# ['momdeportes', 'PinoCalad']
# ['MafeCarrascal', 'DELAESPRIELLAE']
# ['QuinteroCalle']
# ['VickyDavilaH']
# ['ElRepublicano09', 'EnriquePenalosa']
# ['silvioravel']
# ['DELAESPRIELLAE']
# ['samuelrestrepo8', 'WF_LEAL', 'QuinteroCalle', 'CeDemocratico']
# ['mutu_rock', 'QuinteroCalle']
# ['MJDuzan']
# ['QuinteroCalle', 'CarlosF48327173']
# ['QuinteroCalle']
# ['AlfredoRamosM']
# ['AbelCastao2', 'AndresSantana08', 'QuinteroCalle']
# ['matadoreltiempo']
# ['Tuitero1A']
# ['esmegmaj']
# ['diegomatteus']
# ['AdamSmithFree', 'QuinteroCalle']
# ['QuinteroCalle']
# ['PauArizab']
# ['QuinteroCalle']
# ['cheshire2225']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['JulianRoman']
# ['MONYRODRIGUEZOF']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['LeonVaLenciaA']
# []
# ['chuchoagudelo1', 'petrogustavo']
# ['MariaFdaCabal']
# ['MariaFdaCabal']
# ['PalomaSenadora']
# ['SectorMovilidad']
# ['elANTIMILI', 'mane9999', 'AlvaroUribeVel', 'QuinteroCalle']
# ['MafeCarrascal']
# ['QuinteroCalle']
# ['lewisosba', 'AbelCastao2', 'AndresSantana08', 'QuinteroCalle']
# ['iAgua']
# ['Phonetiks']
# ['EstebanSantos10']
# ['Dienarcep', 'WRadioColombia']
# ['NoticiasUno']
# ['giocosas', 'DELAESPRIELLAE', 'petrogustavo', 'monik_soto', 'millersoto', 'juansbeatle', 'luispuyana', 'Horadelaverdad', 'lafm']
# ['FiscaliaCol']
# ['kiki_barraza', 'PoliciaColombia']
# ['jflafaurie']
# ['jflafaurie']
# ['QuinteroCalle']
# ['LuisAlf82940568', 'GustavoBolivar']
# ['Orfeo_43', 'GustavoBolivar', 'MariaFdaCabal', 'CeDemocratico']
# ['mautosiglo21', 'JoseAraujoNig']
# ['mautosiglo21']
# ['QuinteroCalle']
# ['QuinteroCalle']
# ['QuinteroCalle', 'luisbernardov']
# ['SugarMomMom', 'PauArizab', 'espartano3636']
# ['LuisitoComunica']
# ['MafeCarrascal', 'MelissaDelahoz']
# ['RuthQuevedoF']
# ['hernandorduz', 'NataliaDeLaV']
# ['QuinteroCalle', 'quinterocalle']
# []
# ['USAenEspanol']
# []
# ['DonIzquierdo_']
# ['luisjalmar']
# ['DonIzquierdo_']
# []
# ['desararpo']
# ['AquilesCastroSi']
# ['desararpo', 'nacionaloficial']
# ['Arcilausuga']
# ['pedronelospina0']
# ['GranadaSara']
# ['F_Alexander09', 'QuinteroCalle']
# ['gener_usuga']
# ['SoyBocadillo', 'bacillus_sc']
# ['Tolaymaruja', 'nadimcomics']
# ['JulianRoman']
# []
# ['QuinteroCalle']
# ['FranciaMarquezM', 'PauArizab']
# ['FranciaMarquezM', 'PauArizab']
# ['alexysanchezg']
# []
# ['NIDEARVC', 'MarthaNucia']
# ['nathsparkles']
# ['realHugoNorrea', 'Betocoralg', 'nespimo', 'TinCadena', 'hernancadavidma', 'DELAESPRIELLAE']
# ['Betocoralg']
# ['gener_usuga']
# []
# ['QuinteroCalle']
# ['ELTIEMPO']
# ['LuisUrquijo']
# ['joseluisgaviri1']
# ['CDRParcVO']
# ['assemblea']
# ['isaelbal']
# ['QuinteroCalle']
# ['PaulinaSofiaTO']
# ['jusediaz12']
# ['QuinteroCalle']
# ['PaulinaSofiaTO']
# ['jflafaurie']
# ['HOLLMANMORRIS', 'EnriquePenalosa']
# ['CasandroMartell']
# ['Reytorre']
# ['LaMamert4']
# ['KatheObando17']
# ['ErnestoPatioRam']
# []
# ['atribinu']
# ['juanmanuelgalan', 'ClaudiaLopez']
# ['QuinteroCalle']
# ['AndresSantana08', 'QuinteroCalle']
# ['alternoso']
# ['PrensaRural', 'COL_EJERCITO']
# ['juanpisrules']
# ['Alvinsch']
# ['QuinteroCalle']
# ['QuinteroCalle']
# []
# ['QuinteroCalle']
# ['CieloAcua']
# ['CieloAcua']
# ['lauraocampo2017']
# ['VivianaOspinaV']
# ['CieloAcua']
# ['adiazescobar']
# []
# ['RestrepoJCamilo']
# []
# []
# ['TanqueAlCentro']
# ['TanqueAlCentro']
# ['azableh']
# ['JessikPabon', 'la_zana_horita']
# ['LoreBeltran']
# ['QuinteroCalle']
# ['ClaudiaLopez', 'MiguelUribeT']
# ['Cvivianforero', 'leo6609', 'MafeCarrascal', 'DELAESPRIELLAE']
# ['Cvivianforero', 'leo6609', 'MafeCarrascal', 'DELAESPRIELLAE']
# ['leo6609', 'Cvivianforero', 'MafeCarrascal', 'DELAESPRIELLAE']
# ['ojcubillosp', 'petrogustavo', 'HOLLMANMORRIS', 'ClaudiaLopez']
# []
# []
# []
# ['Fabianmendoza']
# ['Colcheck', 'AidaAvellaE']
# ['GustavoRugeles', 'luisfelipehenao']
# ['QuinteroCalle']
# ['PoemPorns']
# ['rockvlzr', 'pablovareladdhh', 'QuinteroCalle']
# ['rockvlzr', 'pablovareladdhh', 'QuinteroCalle']
# ['rockvlzr', 'pablovareladdhh', 'QuinteroCalle']
# ['rockvlzr', 'pablovareladdhh', 'QuinteroCalle']
# ['rockvlzr', 'pablovareladdhh', 'QuinteroCalle']
# ['rockvlzr', 'QuinteroCalle']
# []
# ['artisternst']
# []
# []
# ['SaninPazC', 'aranta_mer']
# ['JOSEFERWOLF', 'MAFAPOBOGOTA', 'Ccajar']
# ['bogotastvu']
# ['bogotastvu']
# []
# ['laviejacucha']
# ['_El_Patriota']
# ['Jesus_Es_Dios']
# ['GustavoRugeles']
# ['alejoeder']
# ['diarioas', 'CarlosFGalan']
# ['QuinteroCalle', 'natiibedoya']
# ['QuinteroCalle']
# ['PaisMenosPeor']
# ['NanyPardo', 'levyrincon', 'MafeCarrascal']
# ['WRadioColombia']
# ['sergio_fajardo']
# []
# ['NanyPardo']

# %%
k = 0
for count in counter:
    if int(counter[count]['DQTweets']) != 0:
        k += 1
        #print(counter[count]['DQTweets'],counter[count]['NTweets'])
print(k,len(counter))
# Out:
# 179 366

# %%
def interaction(typ,usr_id,counter):
    n_user = len(usr_id_scrn)    
    matrix = np.zeros((n_user,n_user))
    
    for i in range(n_user):

        a = usr_id[1][i]

        try:
            if bool(counter[a][typ]): 
                for b, value in counter[a][typ].items():
                    j = np.where(usr_id[1] == int(b))[0][0]
                    matrix[i][j] = int(value)

        except KeyError:continue
        
    return matrix

# %%
RT = interaction('RT',usr_id_scrn,counter)
REP = interaction('Rep',usr_id_scrn,counter)
FF = np.ones_like(RT)

# %%
def norm_symmetrize(matrix):
    matrix = matrix/np.max(matrix)
    return (matrix+matrix.T)/2.

# %%
RT = norm_symmetrize(RT)
REP = norm_symmetrize(REP)
FF = norm_symmetrize(FF)

# %%
W1 = 0.25 
W2 = 0.5
W3 = 0.75
EdgeW = RT*W1 + REP*W2 + FF*W3
